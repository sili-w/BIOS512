# %% [markdown]
# # BIOS512 Assignment #4

# %% [markdown]
# Import the 📈Tidyverse into your `R` session

# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.5     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.0.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# In this assignment we'll be using data from the [TidyTuesday Project](https://github.com/rfordatascience/tidytuesday). Specifically, we'll investigate vaccination rates at US schools. A `CSV` file of the data is located at:
#
# [https://github.com/rfordatascience/tidytuesday/blob/master/data/2020/2020-02-25/measles.csv](https://github.com/rfordatascience/tidytuesday/blob/master/data/2020/2020-02-25/measles.csv)
#
# Get the "raw" data URL and import it into your `R` session using `read_csv`. Remember to capture the data under a variable name of your choosing!

# %%
measles = read_csv(
  'https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-02-25/measles.csv',
  col_types = cols()
)

head(measles)
# Out:
#   index state   year    name                                     type
# 1 1     Arizona 2018-19 A J Mitchell Elementary                  Public
# 2 2     Arizona 2018-19 Academy Del Sol                          Charter
# 3 3     Arizona 2018-19 Academy Del Sol - Hope                   Charter
# 4 4     Arizona 2018-19 Academy Of Mathematics And Science South Charter
# 5 5     Arizona 2018-19 Acclaim Academy                          Charter
# 6 6     Arizona 2018-19 Alfred F Garcia                          Public
#   city    county     district enroll mmr overall xrel xmed xper lat
# 1 Nogales Santa Cruz NA       51     100 -1      NA     NA   NA 31.34782
# 2 Tucson  Pima       NA       22     100 -1      NA     NA   NA 32.22192
# 3 Tucson  Pima       NA       85     100 -1      NA     NA   NA 32.13049
# 4 Phoenix Maricopa   NA       60     100 -1      NA     NA   NA 33.48545
# 5 Phoenix Maricopa   NA       43     100 -1      NA   2.33 2.33 33.49562
# 6 Phoenix Maricopa   NA       36     100 -1      NA     NA   NA 33.43532
#   lng
# 1 -110.9380
# 2 -110.8961
# 3 -111.1170
# 4 -112.1306
# 5 -112.2247
# 6 -112.1168

# %% [markdown]
# The `mmr` column has holds 🤒 measles, mumps, rubella 🤒 vaccination rates for students in each respective school. **If the `mmr` value is not available for a school the `mmr` value is set to -1 in this data set.**
#
# The target `mmr` vaccination rate as [recommended by the CDC](https://www.cdc.gov/mmwr/preview/mmwrhtml/mm5632a3.htm) for schools is 95%.
#
# **Calculate the fraction of schools per state that have vaccination rates greater than the CDC 95%. Capture the output as a table called `df_vacc_rates`.**
#
# You'll need to do use `filter`, `group_by`, and `summarize`.
#
# I.e.
# 1. Filter out schools that don't report `mmr` vaccination rate (keep schools where `mmr >= 0`).
# 1. Group the data by `state`.
# 1. Summarize fraction of vaccination rates above 95%.
#
# 💡Remember `n()` stands for the number or records in a group. Also, `sum(mmr >= 95, na.rm=TRUE)` will count the number of values above or equal to 95.💡

# %%
measles |> filter(state == 'North Carolina')
# Out:
#      index state          year    name                                  type
# 1     1    North Carolina 2018-19 A T Allen Elementary                  NA
# 2     2    North Carolina 2018-19 A.C.E. Academy                        NA
# 3     3    North Carolina 2018-19 ABC of NC Child Develop. Ctr          NA
# 4     4    North Carolina 2018-19 Agape Christian                       NA
# 5     5    North Carolina 2018-19 Agape International Christian Academy NA
# 6     6    North Carolina 2018-19 Ahoskie Christian                     NA
# 7     7    North Carolina 2018-19 Alamance Christian                    NA
# 2080 1762  North Carolina 2018-19 Liberty Christian                     NA
# 2081 1763  North Carolina 2018-19 Moyock Elementary                     NA
# 2082 1764  North Carolina 2018-19 Spruce Pine Montessori                NA
# 2083 1765  North Carolina 2018-19 Starmount Acad of Excellence          NA
# 2084 1766  North Carolina 2018-19 Annunciation Catholic                 NA
# 2085 1767  North Carolina 2018-19 Renaissance Montessori Sch. of Cary   NA
#      city county       district enroll mmr overall xrel xmed xper lat
# 1    NA   Cabarrus     NA       132    -1  100     NA   NA   NA   35.36238
# 2    NA   Cabarrus     NA        44    -1  100     NA   NA   NA   35.30806
# 3    NA   Davidson     NA         1    -1  100     NA   NA   NA   35.99481
# 4    NA   Ashe         NA         3    -1  100     NA   NA   NA   36.42064
# 5    NA   Franklin     NA         1    -1  100     NA   NA   NA   36.03484
# 6    NA   Hertford     NA        32    -1  100     NA   NA   NA   36.27857
# 7    NA   Alamance     NA        15    -1  100     NA   NA   NA   36.07537
# 8    NA   Guilford     NA        79    -1  100     NA   NA   NA   36.01723
# 9    NA   Pasquotank   NA        15    -1  100     NA   NA   NA   36.27771
# 10   NA   Craven       NA        70    -1  100     NA   NA   NA   35.08317
# 11   NA   Alexander    NA        10    -1  100     NA   NA   NA   35.83332
# 12   NA   Alamance     NA       110    -1  100     NA   NA   NA   36.02973
# 13   NA   Wake         NA         0    -1  100     NA   NA   NA   35.85960
# 14   NA   Alamance     NA        89    -1  100     NA   NA   NA   36.17962
# 15   NA   Mecklenburg  NA        11    -1  100     NA   NA   NA   35.14757
# 16   NA   Transylvania NA         3    -1  100     NA   NA   NA   35.27242
# 17   NA   Harnett      NA        40    -1  100     NA   NA   NA   35.27789
# 18   NA   Anson        NA        31    -1  100     NA   NA   NA   35.10538
# 19   NA   Union        NA       109    -1  100     NA   NA   NA   35.05881
# 20   NA   Stanly       NA        46    -1  100     NA   NA   NA   35.22887
# 21   NA   Union        NA        16    -1  100     NA   NA   NA   35.02019
# 22   NA   Randolph     NA        56    -1  100     NA   NA   NA   35.91289
# 23   NA   Guilford     NA        65    -1  100     NA   NA   NA   36.03034
# 24   NA   Lenoir       NA        38    -1  100     NA   NA   NA   35.31448
# 25   NA   Buncombe     NA        35    -1  100     NA   NA   NA   35.59470
# 26   NA   Buncombe     NA        18    -1  100     NA   NA   NA   35.63114
# 27   NA   Buncombe     NA        20    -1  100     NA   NA   NA   35.66220
# 28   NA   Buncombe     NA         9    -1  100     NA   NA   NA   35.56905
# 29   NA   Forsyth      NA        40    -1  100     NA   NA   NA   36.14128
# 30   NA   Carteret     NA        13    -1  100     NA   NA   NA   34.88327
# ⋮    ⋮    ⋮            ⋮        ⋮      ⋮   ⋮       ⋮    ⋮    ⋮    ⋮
# 2056 NA   Cumberland   NA         8    -1  62.5    NA    NA  NA   34.97576
# 2057 NA   Guilford     NA       101    -1  61.4    NA    NA  NA   36.08141
# 2058 NA   Rowan        NA        28    -1  60.7    NA    NA  NA   35.68181
# 2059 NA   Henderson    NA        76    -1  60.5    NA    NA  NA   35.33878
# 2060 NA   Wake         NA        93    -1  60.2    NA    NA  NA   35.74649
# 2061 NA   Alleghany    NA         5    -1  60.0    NA    NA  NA   36.47264
# 2062 NA   Guilford     NA        81    -1  59.3    NA    NA  NA   36.06783
# 2063 NA   Sampson      NA       138    -1  58.0    NA    NA  NA   33.95865
# 2064 NA   Sampson      NA       138    -1  58.0    NA    NA  NA   34.63520
# 2065 NA   Sampson      NA       138    -1  58.0    NA    NA  NA   35.38966
# 2066 NA   Sampson      NA       138    -1  58.0    NA    NA  NA   35.51743
# 2067 NA   Sampson      NA       138    -1  58.0    NA    NA  NA   34.63557
# 2068 NA   Sampson      NA       138    -1  58.0    NA    NA  NA   34.82596
# 2069 NA   Henderson    NA        14    -1  57.1    NA    NA  NA   35.99769
# 2070 NA   Henderson    NA        14    -1  57.1    NA    NA  NA   35.31950
# 2071 NA   Orange       NA        71    -1  56.3    NA    NA  NA   35.93360
# 2072 NA   Wake         NA        89    -1  53.9    NA    NA  NA   35.74541
# 2073 NA   Bertie       NA        37    -1  51.4    NA    NA  NA   36.15798
# 2074 NA   Guilford     NA        56    -1  50.0    NA    NA  NA   36.01263
# 2075 NA   Guilford     NA         4    -1  50.0    NA    NA  NA   35.94913
# 2076 NA   Mecklenburg  NA        19    -1  47.4    NA    NA  NA   35.30510
# 2077 NA   Cumberland   NA        13    -1  46.2    NA    NA  NA   34.62371
# 2078 NA   Cumberland   NA        13    -1  46.2    NA    NA  NA   35.05898
# 2079 NA   Mecklenburg  NA       117    -1  45.3    NA   0.9  NA   35.15489
# 2080 NA   Durham       NA        20    -1  45.0    NA   5.0  NA   36.06362
# 2081 NA   Currituck    NA        85    -1  43.5    NA    NA  NA   36.52490
# 2082 NA   Mitchell     NA         7    -1  42.9    NA    NA  NA   35.91674
# 2083 NA   Mecklenburg  NA        77    -1  40.3    NA    NA  NA   35.13929
# 2084 NA   Craven       NA        23    -1  21.7    NA    NA  NA   34.87682
# 2085 NA   Wake         NA         4    -1  -1.0    NA    NA  NA   35.76823
#      lng
# 1    -80.51297
# 2    -80.67281
# 3    -80.27403
# 4    -81.48704
# 5    -78.49820
# 6    -76.97674
# 7    -79.37108
# 8    -79.70784
# 9    -76.28326
# 10   -77.08342
# 11   -81.33571
# 12   -79.34670
# 13   -78.89905
# 14   -79.51054
# 15   -80.85405
# 16   -82.64830
# 17   -78.97710
# 18   -80.10644
# 19   -80.72276
# 20   -80.22362
# 21   -80.69347
# 22   -79.97546
# 23   -79.83061
# 24   -77.60339
# 25   -82.42872
# 26   -82.55136
# 27   -82.58270
# 28   -82.66841
# 29   -80.16836
# 30   -76.34211
# ⋮    ⋮
# 2056 -78.98852
# 2057 -79.73584
# 2058 -80.43228
# 2059 -82.40358
# 2060 -78.58265
# 2061 -81.05241
# 2062 -79.62688
# 2063 -78.45948
# 2064 -79.24676
# 2065 -81.61923
# 2066 -81.36852
# 2067 -79.24690
# 2068 -78.24310
# 2069 -78.91384
# 2070 -82.46415
# 2071 -79.01621
# 2072 -78.58787
# 2073 -77.21504
# 2074 -79.82582
# 2075 -80.03436
# 2076 -80.95273
# 2077 -79.15916
# 2078 -78.84862
# 2079 -80.90022
# 2080 -78.92544
# 2081 -76.17366
# 2082 -82.06719
# 2083 -80.87051
# 2084 -76.90448
# 2085 -78.74369

# %%
# create the df_vacc_rates here

df = measles |> filter(measles$mmr >=0) |> group_by (state) |> summarize(df_vacc_rates=sum(measles$mmr >= 95,na.rm=TRUE)/n())
df1= measles |> filter(measles$mmr >=0) |> group_by (state) |> summarize(df_vacc_rates=sum(measles$mmr >= 95,na.rm=TRUE)/n())|> arrange(df_vacc_rates)
df1
# Out:
#    state         df_vacc_rates
# 1  California     2.353884
# 2  Illinois       4.356492
# 3  New York       8.050974
# 4  Ohio          11.471052
# 5  Washington    16.928210
# 6  Pennsylvania  17.268695
# 7  Minnesota     21.019460
# 8  Colorado      22.218978
# 9  Arizona       28.594364
# 10 Massachusetts 35.098532
# 11 Texas         41.287300
# 12 Oregon        41.543424
# 13 Missouri      47.834286
# 14 Utah          55.529022
# 15 Connecticut   56.848896
# 16 Arkansas      59.054674
# 17 Montana       64.145594
# 18 South Dakota  89.769437
# 19 North Dakota  93.011111
# 20 Maine         93.792717
# 21 Vermont       99.065089

# %% [markdown]
# Which state (of those that report `mmr`) has the smallest fraction of schools above the CDC target vaccination rate of 95%?

# %%
#California

# %% [markdown]
# **Make a ECDF plot of the school vaccination rates in North Carolina.** Use the `overall` column which reports the "overall" vaccination rate at each school.
#
# ❗️Remember, you can calculate the `y` value for ECDF charts using `row_number`, `mutate`, and `arrange`.

# %%
CDC_95  = measles |> 
  filter(state == 'North Carolina', measles$overall >=0) |> 
  summarize(quant95 = quantile(measles$overall, 0.95))

measles  |>filter(measles$state == 'North Carolina', measles$overall >=0) |>
  select(state, overall) |> mutate(rk = row_number() / n()) |> arrange(overall)|> 
  ggplot(aes(x=overall, y=rk)) + stat_ecdf(geom = "point") + stat_ecdf(geom = "line") +
  geom_vline(xintercept = 95, linetype = "dashed", color='#56b6be') +
  scale_x_continuous(labels = scales::percent_format(scale = 1)) +
  labs(y = "Fraction of schools", x = "Vaccination rate (%)") +
  geom_text(data = CDC_95, label = "CDC recommended\nVaccination rate\n(95%)", x=80, y=0.75) +
  geom_curve(aes(x = 80, y = 0.65, xend = 95, yend = 0.6),
             arrow = arrow(length = unit(0.01, "npc"),type="closed"),
             size = 0.5,
             angle = 90 )
# Out:
# plot without title

# %% [markdown]
# (My solution is below if you want to peek 👀. Uncomment the code, change the cell to `markdown`, and exectute it.)

# %% [markdown]
#  ![](https://github.com/chuckpr/BIOS512/blob/main/assignments/measles-chart.png?raw=true)

# %% [markdown]
# Is the median vaccination rate for NC schools above the CDC recommended target?

# %%
NC_50  = measles |> 
  filter(state == 'North Carolina', measles$overall >=0) |> 
  summarize(quant50 = quantile(measles$overall, 0.5))
NC_50
#Since the median vaccination rate for NC is 87 which is less than 95, so it is not above CDC recommended target
# Out:
#   quant50
# 1 87
